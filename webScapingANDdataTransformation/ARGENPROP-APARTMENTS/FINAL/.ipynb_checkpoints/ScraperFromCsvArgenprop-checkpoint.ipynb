# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Argenprop_links.csv',encoding='utf-8')

# %%
data
# Out:
#    id                                               link
# 0   0  https://www.argenprop.com/inmuebles-venta-barr...
# 1   1  https://www.argenprop.com/inmuebles-venta-barr...
# 2   2  https://www.argenprop.com/inmuebles-venta-barr...
# 3   3  https://www.argenprop.com/inmuebles-venta-barr...
# 4   4  https://www.argenprop.com/inmuebles-venta-barr...

# %%
links=list(data['link'])

# %%
url_base='https://www.argenprop.com'

# %%
import re
import requests
from bs4 import BeautifulSoup as bs

# %%
def cleanData(price,expenses,direcction,coveredArea,bedrooms,antiquity,toilets,environments,garages,condition,provision):
    #price,expenses,direcction,coveredArea,bedrooms
    #antiquity,toilets,environments,garages,condition,provision
    currencyPurchase=price.split()[0]
    pricePurchase=price.split()[1]
    expensesCurrency=expenses.split()[1][0:1]
    expensesPrice=expenses.split()[1][1:]
    coveredArea=coveredArea.split()[0]
    bedrooms=bedrooms.split()[0]
    antiquity=antiquity.split()[0]
    toilets=toilets.split()[0]
    environments=environments.split()[0]
    garages=garages.split()[0]
    return ( currencyPurchase,pricePurchase,expensesCurrency,expensesPrice,direcction,coveredArea,bedrooms,antiquity,toilets,environments,garages,condition,provision )

# %%
name_csv = 'betaArgenProp'

# %%
aparthments=[]

for link in links:
    response = requests.get(link)
    soup=bs(response.content,'html.parser')
    post=soup.find_all('a',attrs={'card'})
    aparthment=[ url_base + n.get('href') for n in post ] 
    aparthments.extend(list(aparthment))

# %%
#len(aparthments)
#aparthments

# %%
listaAparthment=[]
tot=0
error=0
for aparthment in aparthments:
    response = requests.get(aparthment)
    Aparthment=bs(response.content,'html.parser')
    listCaract = Aparthment.find('ul',attrs={'property-main-features'})

    tot=tot+1
    try:
        price=Aparthment.find('p',attrs={'titlebar__price'}).get_text()
        try:
            expenses=Aparthment.find('p',attrs={'titlebar__expenses hide-in-mobile'}).get_text()
        except:
            expenses='    + $32.000 expensas   '
        direcction=Aparthment.find('h3',attrs={'titlebar__address'}).get_text()
        try:
            coveredArea =listCaract.find('li',attrs={'title':'Sup. cubierta'}).find('p',attrs={'strong'}).get_text()
        except:
            coveredArea='0 m² Cubierta'
        bedrooms =listCaract.find('li',attrs={'title':'Dormitorios'}).find('p',attrs={'strong'}).get_text()
        try:
            antiquity =listCaract.find('li',attrs={'title':'Antigüedad'}).find('p',attrs={'strong'}).get_text()
        except:
            antiquity = '10000 años'
        toilets =listCaract.find('li',attrs={'title':'Baños'}).find('p',attrs={'strong'}).get_text()
        environments =listCaract.find('li',attrs={'title':'Ambientes'}).find('p',attrs={'strong'}).get_text()
        try:
            garages =listCaract.find('li',attrs={'title':'Cocheras'}).find('p',attrs={'strong'}).get_text()
        except:
            garages = '0 cochera'
        try:
            condition =listCaract.find('li',attrs={'title':'Estado'}).find('p',attrs={'strong'}).get_text()
        except:
            condition=' '
        try:
            provision =listCaract.find('li',attrs={'title':'Disposición'}).find('p',attrs={'strong'}).get_text()
        except:
            provision=''

        listaAparthment.append( cleanData(price,expenses,direcction,coveredArea,bedrooms,antiquity,toilets,environments,garages,condition,provision) )
    except:
        print('error post')
        error=error+1
print('los casos exitos fueron: {}'.format( (tot-error) ) )
print('los casos fallidos fueron: {}' .format((error) )  )
# Out:
# error post
# error post
# error post
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       4 for aparthment in aparthments:
#       5     response = requests.get(aparthment)
# ----> 6     Aparthment=bs(response.content,'html.parser')
#       7     listCaract = Aparthment.find('ul',attrs={'property-main-features'})
#       9     tot=tot+1
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~/.local/lib/python3.8/site-packages/bs4/builder/_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File /usr/lib/python3.8/html/parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File /usr/lib/python3.8/html/parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File /usr/lib/python3.8/html/parser.py:345, in HTMLParser.parse_starttag(self, i)
#     343     self.handle_startendtag(tag, attrs)
#     344 else:
# --> 345     self.handle_starttag(tag, attrs)
#     346     if tag in self.CDATA_CONTENT_ELEMENTS:
#     347         self.set_cdata_mode(tag)
#
# File ~/.local/lib/python3.8/site-packages/bs4/builder/_htmlparser.py:154, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     152 #print("START", name)
#     153 sourceline, sourcepos = self.getpos()
# --> 154 tag = self.soup.handle_starttag(
#     155     name, None, None, attr_dict, sourceline=sourceline,
#     156     sourcepos=sourcepos
#     157 )
#     158 if tag and tag.is_empty_element and handle_empty_element:
#     159     # Unlike other parsers, html.parser doesn't send separate end tag
#     160     # events for empty-element tags. (It's handled in
#    (...)
#     166     # don't want handle_endtag() to cross off any previous end
#     167     # events for tags of this name.
#     168     self.handle_endtag(name, check_already_closed=False)
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:721, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     716 if (self.parse_only and len(self.tagStack) <= 1
#     717     and (self.parse_only.text
#     718          or not self.parse_only.search_tag(name, attrs))):
#     719     return None
# --> 721 tag = self.element_classes.get(Tag, Tag)(
#     722     self, self.builder, name, namespace, nsprefix, attrs,
#     723     self.currentTag, self._most_recent_element,
#     724     sourceline=sourceline, sourcepos=sourcepos,
#     725     namespaces=namespaces
#     726 )
#     727 if tag is None:
#     728     return tag
#
# File ~/.local/lib/python3.8/site-packages/bs4/element.py:1243, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1241 elif attrs:
#    1242     if builder is not None and builder.cdata_list_attributes:
# -> 1243         attrs = builder._replace_cdata_list_attribute_values(
#    1244             self.name, attrs)
#    1245     else:
#    1246         attrs = dict(attrs)
#
# File ~/.local/lib/python3.8/site-packages/bs4/builder/__init__.py:312, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     310 if self.cdata_list_attributes:
#     311     universal = self.cdata_list_attributes.get('*', [])
# --> 312     tag_specific = self.cdata_list_attributes.get(
#     313         tag_name.lower(), None)
#     314     for attr in list(attrs.keys()):
#     315         if attr in universal or (tag_specific and attr in tag_specific):
#     316             # We have a "class"-type attribute whose string
#     317             # value is a whitespace-separated list of
#     318             # values. Split it into a list.
#
# KeyboardInterrupt:

# %%
listaAparthment
# Out:
# [('USD',
#   '360.000',
#   '$',
#   '38.000',
#   'AV. CABILDO  100',
#   '165',
#   '3',
#   '10000',
#   '4',
#   '4',
#   '1',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '305.000',
#   '$',
#   '60.000',
#   'AV. SANTA FE 3300',
#   '165',
#   '4',
#   '10000',
#   '4',
#   '5',
#   '1',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '555.000',
#   '$',
#   '48.000',
#   'REPUBLICA DE LA INDIA  2900',
#   '130',
#   '3',
#   '15',
#   '3',
#   '4',
#   '1',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '86.000',
#   '$',
#   '8.000',
#   'Republica de la India  2800',
#   '35',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '336.000',
#   '$',
#   '22.000',
#   'Charcas 4000',
#   '75',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '1',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '420.000',
#   '$',
#   '32.000',
#   'REPUBLICA DE LA INDIA  2900',
#   '90',
#   '2',
#   '15',
#   '2',
#   '3',
#   '1',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '645.000',
#   '$',
#   '50.000',
#   'JUAN MARIA GUTIERREZ 3900',
#   '140',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '1',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '227.000',
#   '$',
#   '9.000',
#   'JUAN MARIA GUTIERREZ  3800',
#   '95',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '330.000',
#   '$',
#   '15.000',
#   'Scalabrini Ortiz 1500',
#   '106',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '2',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '215.000',
#   '$',
#   '25.000',
#   'Honduras 3900',
#   '95',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '365.000',
#   '$',
#   '18.000',
#   'BERUTI 3800',
#   '96',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '1.950.000',
#   '$',
#   '32.000',
#   'Castex 3500',
#   '407',
#   '4',
#   '26',
#   '4',
#   '5',
#   '2',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '156.000',
#   '$',
#   '9.000',
#   'PARAGUAY al 5300',
#   '55',
#   '1',
#   '10000',
#   '2',
#   '2',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '150.000',
#   '$',
#   '13.000',
#   'Guatemala 6000',
#   '50',
#   '1',
#   '10000',
#   '2',
#   '2',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '162.000',
#   '$',
#   '21.000',
#   'AVENIDA SANTA FE 3500, Piso 8',
#   '0',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   'Regular ',
#   'Frente '),
#  ('USD',
#   '65.000',
#   '$',
#   '9.500',
#   'Concepción Arenal al 2300',
#   '34',
#   '1',
#   '24',
#   '1',
#   '2',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '79.000',
#   '$',
#   '16.000',
#   'SERRANO entre VERA y RAMIREZ DE VELAZCO',
#   '29',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '126.900',
#   '$',
#   '32.000',
#   'Borges 2100, Piso 1',
#   '47',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '126.999',
#   '$',
#   '32.000',
#   'BORGES 2100',
#   '48',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '1',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '326.000',
#   '$',
#   '32.000',
#   'PARAGUAY  5600',
#   '115',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '1',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '105.000',
#   '$',
#   '16.200',
#   'CONVENCION entre HONDURAS y EL SALVADOR',
#   '36',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '1',
#   ' ',
#   'Frente '),
#  ('USD',
#   '105.000',
#   '$',
#   '1.150',
#   'Gurruchaga 2200, Piso PB',
#   '52',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '220.000',
#   '$',
#   '28.000',
#   'Julian Alvarez 2400, Piso 1',
#   '110',
#   '3',
#   '10000',
#   '1',
#   '4',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '340.000',
#   '$',
#   '10.539',
#   'ARMENIA al 2300',
#   '151',
#   '6',
#   '10000',
#   '4',
#   '7',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '120.000',
#   '$',
#   '8.000',
#   'Güemes  4100 4100',
#   '58',
#   '2',
#   '40',
#   '1',
#   '3',
#   '0',
#   'Bueno ',
#   'Interno '),
#  ('USD',
#   '163.000',
#   '$',
#   '19.900',
#   'santa fe',
#   '0',
#   '3',
#   '10000',
#   '1',
#   '4',
#   '0',
#   'Excelente ',
#   'Contra Frente '),
#  ('USD',
#   '93.000',
#   '$',
#   '32.000',
#   'CARRANZA 2100, Piso 4',
#   '31',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '99.900',
#   '$',
#   '32.000',
#   'Charcas al 5000',
#   '46',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '176.500',
#   '$',
#   '32.000',
#   'Charcas al 5000',
#   '74',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '129.999',
#   '$',
#   '3.000',
#   'Paraguay al 4000',
#   '48',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '63.000',
#   '$',
#   '8.000',
#   'Av. Córdoba 3400, Piso 1',
#   '35',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Muy Bueno ',
#   'Lateral '),
#  ('USD',
#   '90.000',
#   '$',
#   '16.956',
#   'Vidt 1900',
#   '0',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Bueno ',
#   'Frente '),
#  ('USD',
#   '63.000',
#   '$',
#   '32.000',
#   'Charcas al 5000',
#   '24',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '142.000',
#   '$',
#   '32.000',
#   'Borges 2100, Piso 1',
#   '56',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '5',
#   'Excelente ',
#   'Contra Frente '),
#  ('USD',
#   '254.000',
#   '$',
#   '19.800',
#   'Av. Cnel. Diaz 1400, Piso 7',
#   '100',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '1',
#   'Muy Bueno ',
#   'Frente '),
#  ('USD',
#   '165.000',
#   '$',
#   '7.500',
#   'Soler 4200, Piso 9',
#   '66',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '100.000',
#   '$',
#   '12.000',
#   'Paraguay 3500',
#   '44',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'Muy Bueno ',
#   'Frente '),
#  ('USD',
#   '199.000',
#   '$',
#   '14.400',
#   'Av. Santa Fe al 5100',
#   '98',
#   '4',
#   '15',
#   '1',
#   '4',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '220.000',
#   '$',
#   '21.500',
#   'Billinghurst 1600, Piso pb',
#   '88',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '349.000',
#   '$',
#   '70.000',
#   'GUEMES al 4400',
#   '187',
#   '3',
#   '10000',
#   '4',
#   '4',
#   '1',
#   ' ',
#   ''),
#  ('USD',
#   '125.000',
#   '$',
#   '32.000',
#   'Avenida Luis María Campos 1000',
#   '35',
#   '1',
#   '20',
#   '1',
#   '2',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '180.000',
#   '$',
#   '6.500',
#   'Bonpland 1900',
#   '60',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '179.999',
#   '$',
#   '10.000',
#   'MANSILLA  3900',
#   '70',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '300.000',
#   '$',
#   '20.000',
#   'Juncal   3700 9°  3700, Piso 9',
#   '84',
#   '3',
#   '60',
#   '2',
#   '4',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '268.000',
#   '$',
#   '32.000',
#   'REPUBLICA DE LA INDIA  al 3000',
#   '102',
#   '3',
#   '10000',
#   '2',
#   '5',
#   '1',
#   ' ',
#   ''),
#  ('USD',
#   '88.000',
#   '$',
#   '32.000',
#   'Godoy Cruz 2875',
#   '32',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '97.000',
#   '$',
#   '32.000',
#   'Soler al 5500',
#   '34',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '78.000',
#   '$',
#   '32.000',
#   'Av Niceto Vega 5700',
#   '25',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '128.000',
#   '$',
#   '32.000',
#   'Av Niceto Vega 5700',
#   '37',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '300.000',
#   '$',
#   '24.000',
#   'Ruggieri al 2900',
#   '61',
#   '2',
#   '10000',
#   '1',
#   '3',
#   '1',
#   ' ',
#   ''),
#  ('USD',
#   '248.000',
#   '$',
#   '19.500',
#   'Malabia 2200, Piso 3',
#   '125',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '148.000',
#   '$',
#   '32.000',
#   'Av Niceto Vega 5700',
#   '51',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '340.000',
#   '$',
#   '30.000',
#   'AV. LAS HERAS 3900',
#   '119,89',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '0',
#   'Muy Bueno ',
#   ''),
#  ('USD',
#   '198.000',
#   '$',
#   '32.000',
#   'Borges 2100, Piso 1',
#   '73',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '210.000',
#   '$',
#   '23.000',
#   'Lafinur 3100, Piso 7',
#   '0',
#   '3',
#   '10000',
#   '1',
#   '4',
#   '0',
#   'Muy Bueno ',
#   'Contra Frente '),
#  ('USD',
#   '120.000',
#   '$',
#   '21.375',
#   'CONCEPCION ARENAL al 2300',
#   '0',
#   '2',
#   '10000',
#   '1',
#   '3',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '355.000',
#   '$',
#   '64.540',
#   'SANTA FE AV. 3400',
#   '140',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '0',
#   'Bueno ',
#   'Frente '),
#  ('USD',
#   '60.000',
#   '$',
#   '5.200',
#   'SINCLAIR al 3000',
#   '28',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   ' ',
#   'Interno '),
#  ('USD',
#   '270.000',
#   '$',
#   '39.000',
#   'Cabrera , José Antonio 3900',
#   '0',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '2',
#   'Excelente ',
#   'Lateral '),
#  ('USD',
#   '84.000',
#   '$',
#   '11.000',
#   'Cabrera 3900, Piso 5',
#   '32',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '0',
#   'Excelente ',
#   ''),
#  ('USD',
#   '575.000',
#   '$',
#   '32.000',
#   'Cabello 3100',
#   '135',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '1',
#   ' ',
#   ''),
#  ('USD',
#   '109.500',
#   '$',
#   '11.800',
#   'AREVALO 2300, Piso 2',
#   '53',
#   '2',
#   '10000',
#   '1',
#   '3',
#   '0',
#   'Muy Bueno ',
#   'Frente '),
#  ('USD',
#   '262.000',
#   '$',
#   '32.000',
#   'Charcas al 5000',
#   '100',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '230.000',
#   '$',
#   '32.000',
#   'Av Niceto Vega 5700',
#   '67',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '280.000',
#   '$',
#   '15.000',
#   'Av. Luis Maria Campos  100 4°  100, Piso 4',
#   '73',
#   '2',
#   '15',
#   '2',
#   '3',
#   '0',
#   ' ',
#   ''),
#  ('USD',
#   '390.000',
#   '$',
#   '32.000',
#   'Maure 2100',
#   '156',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '1',
#   ' ',
#   ''),
#  ('Consultar',
#   'precio',
#   '$',
#   '32.000',
#   'ARMENIA 2200',
#   '162',
#   '3',
#   '10000',
#   '3',
#   '4',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '157.000',
#   '$',
#   '21.000',
#   'Charcas 3300',
#   '60',
#   '1',
#   '10000',
#   '2',
#   '2',
#   '0',
#   'Excelente ',
#   'Frente '),
#  ('USD',
#   '139.000',
#   '$',
#   '32.000',
#   'SOLER al 3800',
#   '78',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '140.000',
#   '$',
#   '32.000',
#   'Humboldt 2200, Piso 0',
#   '68,50',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   'A Refaccionar ',
#   'Contrafrente '),
#  ('USD',
#   '150.000',
#   '$',
#   '32.000',
#   'Medrano  1300, Piso 1',
#   '106',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '0',
#   'Bueno ',
#   'Lateral '),
#  ('USD',
#   '60.000',
#   '$',
#   '4.400',
#   'Charcas al 5100',
#   '31',
#   '1',
#   '10000',
#   '1',
#   '2',
#   '0',
#   ' ',
#   'Interno '),
#  ('USD',
#   '219.000',
#   '$',
#   '32.000',
#   'Av Niceto Vega 5700',
#   '66',
#   '2',
#   'A',
#   '2',
#   '3',
#   '0',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '350.000',
#   '$',
#   '32.000',
#   'Pereyra Lucena  2500',
#   '105',
#   '2',
#   '10000',
#   '2',
#   '3',
#   '1',
#   ' ',
#   'Contrafrente '),
#  ('USD',
#   '145.000',
#   '$',
#   '20.460',
#   'Paraguay 3500',
#   '67',
#   '2',
#   '10000',
#   '1',
#   '3',
#   '0',
#   'Muy Bueno ',
#   'Contrafrente '),
#  ('USD',
#   '235.000',
#   '$',
#   '16.000',
#   'Av Scalabrini Ortiz al 2200',
#   '89',
#   '3',
#   '10000',
#   '2',
#   '4',
#   '1',
#   ' ',
#   'Frente '),
#  ('USD',
#   '250.000',
#   '$',
#   '35.000',
#   'Ugarteche 2800, Piso 8',
#   '92',
#   '3',
#   '20',
#   '3',
#   '4',
#   '0',
#   'Excelente ',
#   'Contrafrente '),
#  ('USD',
#   '151.551',
#   '$',
#   '32.000',
#   'Godoy Cruz 2875',
#   '50',
#   '1',
#   '10000',
#   '2',
#   '2',
#   '0',
#   ' ',
#   'Frente '),
#  ('USD',
#   '99.583',
#   '$',
#   '32.000',
#   'SOLER 5600',
#   '27',
#   'Monoambiente',
#   '10000',
#   '1',
#   '1',
#   '1',
#   ' ',
#   'Contrafrente ')]

# %%
print('el porcentaje de casos exitosos fue de: {}' .format(((tot-error)/tot )  ))
# Out:
# el porcentaje de casos exitosos fue de: 0.9634146341463414

# %%
csv_headers=['currencyPurchase','pricePurchase','expensesCurrency','expensesPrice','direcction','coveredArea','bedrooms','antiquity','toilets','environments','garages','condition','provision']

# %%
def _save_cars(data_car,name,csv_headers):
    import csv
    out_file_name = '{x}.csv'.format(x=name)
    
    with open(out_file_name, mode='w') as f:
        writer = csv.writer(f)
        writer.writerow(csv_headers)

        for data in data_car:
            row =data
            writer.writerow(row)

# %%
_save_cars(listaAparthment,name_csv,csv_headers)
