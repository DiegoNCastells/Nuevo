# %%
import os
import re
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
con=sql.connect('brandCars.db')
data = pd.read_sql('SELECT nameBrand FROM brandCars',con)

# %%
df=pd.read_csv('Peugeot 208_cars_alfa.csv',encoding='utf-8')

# %%
df['name']
# Out:
# 0                 Peugeot 208 1.6 Allure
# 1                   Peugeot 208 1.2 Like
# 2                 Peugeot 208 1.6l Style
# 3                 Peugeot 208 1.6l Style
# 4      Peugeot 208 1.6l Active Tiptronic
# 5                 Peugeot 208 1.6l Style
# 6                      Peugeot 208 Style
# 7                Peugeot 208 1.6l Active
# 8       Peugeot 208 1.6 Feline Tiptronic
# 9                 Peugeot 208 1.6l Style
# 10                   Peugeot 208 1.6 Gti
# 11    Peugeot 208 1.5 Allure Touchscreen
# 12                Peugeot 208 1.6l Style
# 13                Peugeot 208 1.6 Feline
# 14    Peugeot 208 1.5 Allure Touchscreen
# 15                Peugeot 208 1.6 Allure
# 16                Peugeot 208 1.6 Gt Thp
# 17             Peugeot 208 1.6 Like Pack
# 18                Peugeot 208 1.6 Allure
# 19    Peugeot 208 1.6 Allure Touchscreen
# 20                Peugeot 208 1.6 Active
# 21                  Peugeot 208 1.2 Like
# 22     Peugeot 208 1.6l Feline Tiptronic
# 23                Peugeot 208 1.6 Active
# 24                  Peugeot 208 1.2 Like
# 25    Peugeot 208 1.5 Allure Touchscreen
# 26           Peugeot 208 Style Tiptronic
# 27                Peugeot 208 1.5 Active
# 28                   Peugeot 208 1.6 Gti
# 29                Peugeot 208 1.5 Active
# 30                  Peugeot 208 1.2 Like
# 31                Peugeot 208 1.6 Feline
# 32                Peugeot 208 1.6 Feline
# 33      Peugeot 208 1.6 Feline Tiptronic
# 34             Peugeot 208 1.6 Like Pack
# 35                Peugeot 208 1.6 Allure
# 36      Peugeot 208 1.6 Feline Tiptronic
# 37                Peugeot 208 1.5 Active
# 38                Peugeot 208 1.6l Style
# 39                      Peugeot 208 Like
# 40             Peugeot 208 1.6 Like Pack
# 41                Peugeot 208 1.6 Feline
# Name: name, dtype: object

# %%
def Brand_M(marcas,auto):
    try:
            for x in marcas:
                if( str(x[0]) in auto ):
                    auto = auto.replace(x[0],'')
                    modelo=auto.split()[0] 
                    marca = x[0]
                    motor=re.findall(r"[-+]?(?:\d*\.\d+|\d+)",auto)
                    auto=auto.split(str(motor[0]))  
                    motor=motor[1]
                    line=auto[1].split()
                    #hasta aca anda bien
                    #print(line)
                    linea=""
                    for i in range(1,len(line)):
                        linea=linea+' '+line[i]
                    #print(linea)
                    #print(linea[1])
                    return (marca,modelo,motor,linea)
    except:
        return None

# %%
marcas=np.array(data.iloc[ 1:,0:1])
autos=np.array(df['name'])

# %%
tot=[]
for auto in autos:
    #print(auto)
    aux = Brand_M(marcas,auto)
    if aux != None:
        tot.append(aux)
df = pd.DataFrame(tot)
df
# Out:
#           0    1    2                    3
# 0   Peugeot  208  1.6               Allure
# 1   Peugeot  208  1.2                 Like
# 2   Peugeot  208  1.6                Style
# 3   Peugeot  208  1.6                Style
# 4   Peugeot  208  1.6     Active Tiptronic
# 5   Peugeot  208  1.6                Style
# 6   Peugeot  208  1.6               Active
# 7   Peugeot  208  1.6     Feline Tiptronic
# 8   Peugeot  208  1.6                Style
# 9   Peugeot  208  1.6                  Gti
# 10  Peugeot  208  1.5   Allure Touchscreen
# 11  Peugeot  208  1.6                Style
# 12  Peugeot  208  1.6               Feline
# 13  Peugeot  208  1.5   Allure Touchscreen
# 14  Peugeot  208  1.6               Allure
# 15  Peugeot  208  1.6               Gt Thp
# 16  Peugeot  208  1.6            Like Pack
# 17  Peugeot  208  1.6               Allure
# 18  Peugeot  208  1.6   Allure Touchscreen
# 19  Peugeot  208  1.6               Active
# 20  Peugeot  208  1.2                 Like
# 21  Peugeot  208  1.6     Feline Tiptronic
# 22  Peugeot  208  1.6               Active
# 23  Peugeot  208  1.2                 Like
# 24  Peugeot  208  1.5   Allure Touchscreen
# 25  Peugeot  208  1.5               Active
# 26  Peugeot  208  1.6                  Gti
# 27  Peugeot  208  1.5               Active
# 28  Peugeot  208  1.2                 Like
# 29  Peugeot  208  1.6               Feline
# 30  Peugeot  208  1.6               Feline
# 31  Peugeot  208  1.6     Feline Tiptronic
# 32  Peugeot  208  1.6            Like Pack
# 33  Peugeot  208  1.6               Allure
# 34  Peugeot  208  1.6     Feline Tiptronic
# 35  Peugeot  208  1.5               Active
# 36  Peugeot  208  1.6                Style
# 37  Peugeot  208  1.6            Like Pack
# 38  Peugeot  208  1.6               Feline

# %%
def Brand_M(marcas,auto):
    try:
            for x in marcas:
                if( str(x[0]) in auto ):
                    auto = auto.replace(x[0],'')
                    modelo=auto.split()[0] 
                    marca = x[0]
                    motor=re.findall(r"[-+]?(?:\d*\.\d+|\d+)",auto)
                    auto=auto.split(str(motor[0]))  
                    motor=motor[1]
                    line=auto[1].split()
                    #hasta aca anda bien
                    #print(line)
                    linea=""
                    for i in range(1,len(line)):
                        linea=linea+' '+line[i]
                    #print(linea)
                    #print(linea[1])
                    return (marca,modelo,motor,linea)
    except:
        return None

# %%
print(Brand_M(marcas,str('Peugeot 208 1.6 Allure x')))
# Out:
#  Allure x
# ('Peugeot', '208', '1.6', ' Allure x')
